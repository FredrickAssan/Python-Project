# %%
name = input("Enter your Name?")
age = int(input("Enter your Age?"))

if age >= 18:
    age_status = "Adult"
else:
    age_status = "Minor"
    
gpa = float(input ("What is your GPA?"))

if gpa > 4.0:
    print ("Invalid gpa")
elif gpa >= 3.6:
    deans_list = "Yes"
else:
    deans_list = "No"

courses = int(input("How many courses are you enrolled in?"))
string_list = []
for i in range(courses):
    s = input(f"Course # {i+1}:")
    string_list.append(s)
   
student_profile = {}
student_profile ["name"] = name
student_profile ["age"] = age
student_profile ["gpa"] = gpa
student_profile ["num_courses"] = courses
student_profile ["age_status"] = age_status
student_profile ["Deans_List"] = deans_list

print("========STUDENT PROFILE========")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Age Status: {age_status}")
print(f"GPA: {gpa}")
print(f"Deans List: {deans_list}")
print(f"Num_Courses:{int(courses)}")
print(f"Courses: {string_list}")
print("===============================")
# Out:
# Enter your Name? Arthur Fredrick Assan
# Enter your Age? 20
# What is your GPA? 3.5
# How many courses are you enrolled in? 4
# Course # 1: Programming in Python
# Course # 2: Database Management System
# Course # 3: Computer Organization and Architecture
# Course # 4: Software Engineering
# ========STUDENT PROFILE========
# Name: Arthur Fredrick Assan
# Age: 20
# Age Status: Adult
# GPA: 3.5
# Deans List: No
# Num_Courses:4
# Courses: ['Programming in Python ', 'Database Management System', 'Computer Organization and Architecture', 'Software Engineering']
# ===============================
